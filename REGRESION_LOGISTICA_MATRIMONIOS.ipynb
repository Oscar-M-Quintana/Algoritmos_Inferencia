# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Cargar el dataset
url = 'https://catalogo.datos.gba.gob.ar/dataset/2e29c7d5-aadc-4cbb-90bd-c2aed5906449/resource/bf0709fe-db4f-4214-a92e-f75a967d73cc/download/matrimonios-2016_2022.csv'
data = pd.read_csv(url)

# %%
print(df.to_string())
# Out:
#        anio  mes  zona  municipio_id                    municipio_nombre                 partido                                   delegacion            tipo  cantidad
# 0      2016    1    19          6007                       Adolfo Alsina           ADOLFO ALSINA                                       CARHUE  diferente sexo         2
# 1      2016    1    19          6007                       Adolfo Alsina           ADOLFO ALSINA                                       RIVERA  diferente sexo         2
# 2      2016    1     5          6021                             Alberti                 ALBERTI                                      ALBERTI  diferente sexo         1
# 3      2016    1    18          6028                     Almirante Brown         ALMIRANTE BROWN                         ADROGUE - ALTE BROWN  diferente sexo         8
# ...

# %%
# Preprocesamiento
data = data[['anio', 'mes', 'zona', 'municipio_id', 'tipo']].dropna()
data['tipo'] = data['tipo'].apply(lambda x: 1 if x == 'diferente sexo' else 0)

# %%
# Convertir variables categóricas a variables dummies
data = pd.get_dummies(data, columns=['zona', 'municipio_id'], drop_first=True)

# %%
# Separar variables predictoras y objetivo
X = data.drop('tipo', axis=1)
y = data['tipo']

# %%
# Dividir en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Entrenar el modelo de regresión logística
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
# Out:
# c:\Users\20315079196\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=10000)

# %%
# Predicciones
y_pred = model.predict(X_test)

# %%
# Evaluación del modelo
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9371596762325239
# Confusion Matrix:
#  [[3987  257]
#  [ 170 2381]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      4244
#            1       0.90      0.93      0.92      2551
#
#     accuracy                           0.94      6795
#    macro avg       0.93      0.94      0.93      6795
# weighted avg       0.94      0.94      0.94      6795
